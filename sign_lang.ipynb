# %%
import cv2
import os
import numpy as np
import mediapipe as mp
from scipy.ndimage import gaussian_filter1d
from tensorflow.keras.models import load_model
from sklearn.model_selection import train_test_split
from tensorflow.keras import layers, models

# %%
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=True, max_num_hands=1, min_detection_confidence=0.7)
mp_drawing = mp.solutions.drawing_utils
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1724587932.346999  255471 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1

# %%
# Paths
dataset_path = '/Users/mantri/Desktop/HandGesture_Recognition/American'
processed_dataset_path = '/Users/mantri/Desktop/HandGesture_Recognition/American_processed_dataset'

# %%
# Create a directory for processed data
if not os.path.exists(processed_dataset_path):
    os.makedirs(processed_dataset_path)
# Out:
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
classes = list('abcdefghijklmnopqrstuvwxyz')

# %%
def extract_landmarks(image):
    # Process the image to detect hand landmarks
    results = hands.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    
    if results.multi_hand_landmarks:
        hand_landmarks = results.multi_hand_landmarks[0]
        
        # Get the bounding box around the hand
        h, w, _ = image.shape
        x_min, y_min = w, h
        x_max, y_max = 0, 0
        for lm in hand_landmarks.landmark:
            x, y = int(lm.x * w), int(lm.y * h)
            if x < x_min: x_min = x
            if y < y_min: y_min = y
            if x > x_max: x_max = x
            if y > y_max: y_max = y

        # Add padding to the bounding box
        padding = 20  # You can adjust this padding value
        x_min = max(0, x_min - padding)
        y_min = max(0, y_min - padding)
        x_max = min(w, x_max + padding)
        y_max = min(h, y_max + padding)

        # Crop the image to the bounding box
        cropped_image = image[y_min:y_max, x_min:x_max]

        # Calculate landmarks on the cropped image
        cropped_results = hands.process(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))
        if cropped_results.multi_hand_landmarks:
            cropped_hand_landmarks = cropped_results.multi_hand_landmarks[0]
            landmarks = []
            for lm in cropped_hand_landmarks.landmark:
                landmarks.append(lm.x)
                landmarks.append(lm.y)
            return landmarks
    return None
# Out:
# W0000 00:00:1724587932.377989  258713 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
# # Process the dataset
# for label in classes:
#     label_path = os.path.join(dataset_path, label)
#     processed_label_path = os.path.join(processed_dataset_path, label)

#     if not os.path.exists(processed_label_path):
#         os.makedirs(processed_label_path)

#     for image_name in os.listdir(label_path):
#         img_path = os.path.join(label_path, image_name)
#         img = cv2.imread(img_path)

#         # Extract landmarks
#         landmarks = extract_landmarks(img)
#         if landmarks:
#             # Save the landmarks as a numpy array
#             landmark_path = os.path.join(processed_label_path, image_name.split('.')[0] + '.npy')
#             np.save(landmark_path, np.array(landmarks))

# print("Dataset converted successfully. Landmarks are saved.")
# Out:
# W0000 00:00:1724587932.388072  258715 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
# Paths

classes = list('abcdefghijklmnopqrstuvwxyz')  # Include  alphabets

# %%
# Load processed data
landmarks = []
labels = []

for label in classes:
    label_path = os.path.join(processed_dataset_path, label)
    for landmark_file in os.listdir(label_path):
        landmark_path = os.path.join(label_path, landmark_file)
        landmarks.append(np.load(landmark_path))
        labels.append(classes.index(label))

# %%
# Convert to numpy arrays
landmarks = np.array(landmarks)
labels = np.array(labels)

# Normalize the landmarks
landmarks = landmarks / np.max(landmarks)

# Reshape landmarks for CNN input
num_landmarks = landmarks.shape[1] // 2
landmarks = landmarks.reshape(-1, num_landmarks, 2, 1)  # Reshape to (samples, num_landmarks, 2, 1) for CNN

# %%
# Split the dataset
train_landmarks, val_landmarks, train_labels, val_labels = train_test_split(landmarks, labels, test_size=0.2,
                                                                            random_state=42)

# %%
model = models.Sequential([
    layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(num_landmarks, 2, 1)),
    layers.MaxPooling2D((2, 1), padding='valid'),
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 1), padding='valid'),
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D((2, 1), padding='valid'),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5), 
    layers.Dense(len(classes), activation='softmax')
])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_landmarks, train_labels, epochs=100, validation_data=(val_landmarks, val_labels))

# Evaluate the model
val_loss, val_acc = model.evaluate(val_landmarks, val_labels)
print(f"Validation accuracy: {val_acc:.4f}")

# Save the trained model
model.save('sign_lang.keras')
# Out:
# Epoch 1/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.6428 - loss: 1.2006 - val_accuracy: 0.9897 - val_loss: 0.0457
# Epoch 2/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9779 - loss: 0.0883 - val_accuracy: 0.9924 - val_loss: 0.0277
# Epoch 3/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9847 - loss: 0.0601 - val_accuracy: 0.9960 - val_loss: 0.0146
# Epoch 4/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9887 - loss: 0.0434 - val_accuracy: 0.9955 - val_loss: 0.0151
# Epoch 5/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9925 - loss: 0.0279 - val_accuracy: 0.9972 - val_loss: 0.0103
# Epoch 6/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9933 - loss: 0.0266 - val_accuracy: 0.9978 - val_loss: 0.0097
# Epoch 7/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9939 - loss: 0.0217 - val_accuracy: 0.9979 - val_loss: 0.0082
# Epoch 8/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9950 - loss: 0.0177 - val_accuracy: 0.9971 - val_loss: 0.0096
# Epoch 9/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9951 - loss: 0.0180 - val_accuracy: 0.9966 - val_loss: 0.0125
# Epoch 10/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9964 - loss: 0.0125 - val_accuracy: 0.9979 - val_loss: 0.0095
# Epoch 11/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9973 - loss: 0.0112 - val_accuracy: 0.9986 - val_loss: 0.0067
# Epoch 12/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9966 - loss: 0.0109 - val_accuracy: 0.9987 - val_loss: 0.0061
# Epoch 13/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9969 - loss: 0.0091 - val_accuracy: 0.9984 - val_loss: 0.0091
# Epoch 14/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9964 - loss: 0.0110 - val_accuracy: 0.9984 - val_loss: 0.0058
# Epoch 15/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9974 - loss: 0.0096 - val_accuracy: 0.9988 - val_loss: 0.0064
# Epoch 16/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.9983 - val_loss: 0.0088
# Epoch 17/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9978 - loss: 0.0075 - val_accuracy: 0.9990 - val_loss: 0.0064
# Epoch 18/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9981 - loss: 0.0067 - val_accuracy: 0.9983 - val_loss: 0.0089
# Epoch 19/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9972 - loss: 0.0103 - val_accuracy: 0.9984 - val_loss: 0.0095
# Epoch 20/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9987 - val_loss: 0.0077
# Epoch 21/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9985 - val_loss: 0.0081
# Epoch 22/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9978 - loss: 0.0096 - val_accuracy: 0.9986 - val_loss: 0.0103
# Epoch 23/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9984 - loss: 0.0051 - val_accuracy: 0.9989 - val_loss: 0.0100
# Epoch 24/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9979 - loss: 0.0085 - val_accuracy: 0.9990 - val_loss: 0.0069
# Epoch 25/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9985 - loss: 0.0050 - val_accuracy: 0.9992 - val_loss: 0.0069
# Epoch 26/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9986 - loss: 0.0048 - val_accuracy: 0.9983 - val_loss: 0.0110
# Epoch 27/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9980 - loss: 0.0071 - val_accuracy: 0.9988 - val_loss: 0.0091
# Epoch 28/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9984 - loss: 0.0055 - val_accuracy: 0.9989 - val_loss: 0.0075
# Epoch 29/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9985 - loss: 0.0046 - val_accuracy: 0.9989 - val_loss: 0.0096
# Epoch 30/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9972 - val_loss: 0.0168
# Epoch 31/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.9986 - val_loss: 0.0091
# Epoch 32/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9981 - val_loss: 0.0098
# Epoch 33/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9990 - val_loss: 0.0079
# Epoch 34/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9970 - val_loss: 0.0209
# Epoch 35/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9986 - loss: 0.0050 - val_accuracy: 0.9990 - val_loss: 0.0081
# Epoch 36/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9991 - val_loss: 0.0086
# Epoch 37/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9990 - loss: 0.0040 - val_accuracy: 0.9983 - val_loss: 0.0128
# Epoch 38/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9982 - loss: 0.0062 - val_accuracy: 0.9988 - val_loss: 0.0121
# Epoch 39/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9982 - loss: 0.0074 - val_accuracy: 0.9993 - val_loss: 0.0083
# Epoch 40/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9993 - loss: 0.0019 - val_accuracy: 0.9990 - val_loss: 0.0100
# Epoch 41/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 0.9987 - val_loss: 0.0166
# Epoch 42/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9991 - loss: 0.0045 - val_accuracy: 0.9990 - val_loss: 0.0140
# Epoch 43/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9976 - val_loss: 0.0120
# Epoch 44/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9992 - loss: 0.0035 - val_accuracy: 0.9987 - val_loss: 0.0102
# Epoch 45/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9991 - val_loss: 0.0099
# Epoch 46/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9990 - loss: 0.0039 - val_accuracy: 0.9982 - val_loss: 0.0174
# Epoch 47/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9994 - loss: 0.0018 - val_accuracy: 0.9982 - val_loss: 0.0137
# Epoch 48/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9982 - loss: 0.0113 - val_accuracy: 0.9990 - val_loss: 0.0080
# Epoch 49/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9993 - loss: 0.0031 - val_accuracy: 0.9990 - val_loss: 0.0129
# Epoch 50/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9994 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0097
# Epoch 51/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9990 - loss: 0.0042 - val_accuracy: 0.9984 - val_loss: 0.0149
# Epoch 52/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9990 - loss: 0.0032 - val_accuracy: 0.9989 - val_loss: 0.0095
# Epoch 53/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9996 - loss: 0.0016 - val_accuracy: 0.9982 - val_loss: 0.0128
# Epoch 54/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9993 - loss: 0.0029 - val_accuracy: 0.9986 - val_loss: 0.0156
# Epoch 55/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9987 - val_loss: 0.0128
# Epoch 56/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9988 - val_loss: 0.0117
# Epoch 57/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9988 - loss: 0.0062 - val_accuracy: 0.9986 - val_loss: 0.0093
# Epoch 58/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9988 - val_loss: 0.0084
# Epoch 59/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9988 - val_loss: 0.0148
# Epoch 60/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9992 - loss: 0.0033 - val_accuracy: 0.9988 - val_loss: 0.0077
# Epoch 61/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.9987 - val_loss: 0.0134
# Epoch 62/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9992 - loss: 0.0038 - val_accuracy: 0.9987 - val_loss: 0.0129
# Epoch 63/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9980 - val_loss: 0.0172
# Epoch 64/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0030 - val_accuracy: 0.9990 - val_loss: 0.0107
# Epoch 65/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9993 - loss: 0.0042 - val_accuracy: 0.9991 - val_loss: 0.0100
# Epoch 66/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9992 - val_loss: 0.0097
# Epoch 67/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0020 - val_accuracy: 0.9989 - val_loss: 0.0096
# Epoch 68/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9992 - loss: 0.0029 - val_accuracy: 0.9990 - val_loss: 0.0157
# Epoch 69/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9991 - loss: 0.0048 - val_accuracy: 0.9990 - val_loss: 0.0118
# Epoch 70/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0026 - val_accuracy: 0.9991 - val_loss: 0.0139
# Epoch 71/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9993 - loss: 0.0029 - val_accuracy: 0.9987 - val_loss: 0.0147
# Epoch 72/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 0.9991 - val_loss: 0.0121
# Epoch 73/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.9993 - loss: 0.0030 - val_accuracy: 0.9990 - val_loss: 0.0090
# Epoch 74/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0136
# Epoch 75/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.9990 - val_loss: 0.0164
# Epoch 76/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9988 - val_loss: 0.0149
# Epoch 77/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 13s 8ms/step - accuracy: 0.9996 - loss: 0.0020 - val_accuracy: 0.9987 - val_loss: 0.0122
# Epoch 78/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9989 - val_loss: 0.0122
# Epoch 79/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9992 - loss: 0.0034 - val_accuracy: 0.9987 - val_loss: 0.0198
# Epoch 80/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9989 - loss: 0.0081 - val_accuracy: 0.9987 - val_loss: 0.0187
# Epoch 81/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - accuracy: 0.9990 - loss: 0.0057 - val_accuracy: 0.9989 - val_loss: 0.0116
# Epoch 82/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9990 - val_loss: 0.0122
# Epoch 83/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0017 - val_accuracy: 0.9988 - val_loss: 0.0164
# Epoch 84/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9991 - val_loss: 0.0158
# Epoch 85/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9990 - val_loss: 0.0117
# Epoch 86/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 0.9991 - val_loss: 0.0135
# Epoch 87/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0039 - val_accuracy: 0.9988 - val_loss: 0.0127
# Epoch 88/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9989 - loss: 0.0057 - val_accuracy: 0.9989 - val_loss: 0.0175
# Epoch 89/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0026 - val_accuracy: 0.9989 - val_loss: 0.0251
# Epoch 90/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9994 - loss: 0.0036 - val_accuracy: 0.9991 - val_loss: 0.0148
# Epoch 91/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9990 - val_loss: 0.0162
# Epoch 92/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9987 - loss: 0.0091 - val_accuracy: 0.9990 - val_loss: 0.0143
# Epoch 93/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9992 - loss: 0.0035 - val_accuracy: 0.9986 - val_loss: 0.0147
# Epoch 94/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0019 - val_accuracy: 0.9990 - val_loss: 0.0160
# Epoch 95/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9993 - loss: 0.0045 - val_accuracy: 0.9990 - val_loss: 0.0175
# Epoch 96/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0031 - val_accuracy: 0.9989 - val_loss: 0.0176
# Epoch 97/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9992 - loss: 0.0059 - val_accuracy: 0.9988 - val_loss: 0.0208
# Epoch 98/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9995 - loss: 0.0037 - val_accuracy: 0.9983 - val_loss: 0.0195
# Epoch 99/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9993 - loss: 0.0025 - val_accuracy: 0.9991 - val_loss: 0.0127
# Epoch 100/100
# 1670/1670 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9997 - loss: 0.0021 - val_accuracy: 0.9977 - val_loss: 0.0177
# 418/418 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9983 - loss: 0.0107
# Validation accuracy: 0.9977

# %%
# Load the model
model = load_model('sign_lang.keras')

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=True, max_num_hands=1, min_detection_confidence=0.7)
mp_drawing = mp.solutions.drawing_utils

# Parameters
classes = list('abcdefghijklmnopqrstuvwxyz')
# Out:
# I0000 00:00:1724588852.974918  255471 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 88), renderer: Apple M1

# %%
def smooth_landmarks(landmarks):
    return gaussian_filter1d(landmarks, sigma=2)

# %%
# Function to extract hand landmarks
def extract_landmarks(image):
    results = hands.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    if results.multi_hand_landmarks:
        hand_landmarks = results.multi_hand_landmarks[0]
        landmarks = []
        for lm in hand_landmarks.landmark:
            landmarks.append(lm.x)
            landmarks.append(lm.y)
        return np.array(landmarks).flatten()
    return None

# %%
def predict_sign(landmarks):
    if landmarks is None:
        return 'Unknown'

    # Smooth the landmarks
    landmarks = smooth_landmarks(landmarks)

    # Reshape landmarks for CNN input
    num_landmarks = 21  # MediaPipe hands model provides 21 landmarks
    landmarks = landmarks.reshape(1, num_landmarks, 2, 1)  # Adjust this to (1, num_landmarks, 2, 1)

    # Ensure input shape matches model's input shape
    if landmarks.shape[1:] != (num_landmarks, 2, 1):
        raise ValueError(f"Expected input shape (1, {num_landmarks}, 2, 1), but got {landmarks.shape}")

    pred = model.predict(landmarks)
    return classes[np.argmax(pred)]

# %%
# Capture video from webcam
cap = cv2.VideoCapture(0)

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Flip the frame
    frame = cv2.flip(frame, 1)

    # Extract landmarks
    landmarks = extract_landmarks(frame)
    if landmarks is not None:
        # Draw landmarks
        mp_drawing.draw_landmarks(frame, hands.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)).multi_hand_landmarks[0],
                                  mp_hands.HAND_CONNECTIONS)
        # Predict the sign
        sign = predict_sign(landmarks)

        # Display the sign
        cv2.putText(frame, sign, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 2, (255, 0, 0), 3, cv2.LINE_AA)

    # Display the frame
    cv2.imshow('Sign Language Detection', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
hands.close()
cap.release()
cv2.destroyAllWindows()
# Out:
# W0000 00:00:1724588853.002701  274443 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1724588853.009975  274443 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
